# %%
import numpy as np
with open("finaldata.txt" , encoding="utf-8") as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(chunks)>3]

# %%
def parsed_data(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split("\n")
    username = sep_chunk[0]
    if (len(sep_chunk) > 5):
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace("," , ""))
        no_of_followers = float(sep_chunk[2].split(" followers")[0].replace(",", "").replace("K" , "").replace("M",""))
        if "K" in sep_chunk[2]:
            no_of_followers = int(no_of_followers * 1000)
        elif 'M' in sep_chunk[2]:
            no_of_followers = int(no_of_followers*1000000)
        else:
            no_of_followers = int(no_of_followers)
        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K" , "").replace("M",""))
        if "K" in sep_chunk[2]:
            no_of_following = int(no_of_following * 1000)
        elif 'M' in sep_chunk[2]:
            no_of_following = int(no_of_following*1000000)
        else:
            no_of_following = int(no_of_following)
        name = sep_chunk[4]
        type_of_page = sep_chunk[5]
        bio = sep_chunk[6]
    else:
        no_of_posts = np.nan
        no_of_followers = np.nan
        no_of_following = np.nan
        name = ''
        type_of_page = 'unknown'
        bio = ''
    return {'username':username, 'no_of_posts': no_of_posts,'no_of_followers': no_of_followers, 'no_of_following':no_of_following,'name': name,'type_of_page': type_of_page,'bio': bio}

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunks = parsed_data(chunk)
    all_chunks.append(parsed_chunks)

# %%
import json
s = json.dumps(all_chunks , indent=4)
with open("data.json" , "w") as f:
    f.write(s)

# %% [markdown]
# # maximum no of posts

# %%
max = 0
for chunk in all_chunks:
    if (max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_posts = chunk
print(chunk_with_max_posts['username'],"- no. of posts: ",chunk_with_max_posts['no_of_posts'])
# Out:
# startuphub_blr - no. of posts:  2300

# %% [markdown]
# # maximum no of followers

# %%
max_followers = 0
for chunk in all_chunks:
    if (max_followers < chunk['no_of_followers']):
        max_followers = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers['username'], "- no. of followers: ", chunk_with_max_followers['no_of_followers'])
# Out:
# _anujsinghal - no. of followers:  681000

# %% [markdown]
# # maximum no of following

# %%
max_followings = 0
for chunk in all_chunks:
    if (max_followings < chunk['no_of_following']):
        max_followings = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following['username'],"- total no. of people following: ",chunk_with_max_following['no_of_following'])
# Out:
# bangalore_tech_bro - total no. of people following:  890000

# %% [markdown]
# # total count of categories present

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"total categories present : {len(categories)}")
# Out:
# total categories present : 34
